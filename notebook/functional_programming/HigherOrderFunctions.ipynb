// %%
val numbers = listOf(1,2,3,4,5)
val moreThan2: (Int) -> Boolean = { it > 2}
println(numbers.any(moreThan2))
// Out:
// true

// %% [markdown]
// # Higher Order Functions
//
// Higher order functions are functions that can either accept other functions as parameters or return a function as a result.

// %%
repeat(times = 5) {
    index -> println("$index")
}
// Out:
// 0
// 1
// 2
// 3
// 4
