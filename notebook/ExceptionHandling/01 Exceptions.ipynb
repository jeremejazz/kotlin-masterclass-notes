// %% [markdown]
// # Exceptions
//
// - we get an error message and ethe execution stops
// -
// ```kotlin
// fun errorCode(){
//     val invalidNumber = "#z1"
//     val result = invalidNumber.toInt()
//
// }
// ```
//
// ```kotlin
//
// fun aveSalaryOrException(amount:Int, months: Int): Int{
//     if(amount ==0){
//         throw IllegalArgumentException("Invalid number")
//     }else if (months == 0){
//         throw IllegalArgumentException("Invalid number")
//     }
//     return amount / months
// }
// ```
